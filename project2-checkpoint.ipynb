# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
tv=pd.read_csv("project2.csv")

# %%
tv
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 907    SONY     Full HD LED     43          44999           57900
# 908    SONY     Full HD LED     40          41499           51900
# 909    SONY    Ultra HD LED     65         149990          184990
# 910    SONY          HD LED     32          32900           32900
# 911    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating
# 0              VIDAA     4.3
# 1            Android     4.4
# 2            Android     4.3
# 3            Android     4.4
# ...

# %%
a=tv.copy()

# %%
tv.shape
# Out:
# (912, 7)

# %%
tv.head()
# Out:
#      Brand     Resolution  Size   Selling Price  Original Price  \
# 0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1     TCL   QLED Ultra HD     55          52999          129990
# 2  realme          HD LED     32          13999           17999
# 3      Mi          HD LED     32          14999           19999
# 4  realme          HD LED     32          12999           21999
#
#   Operating System  Rating
# 0            VIDAA     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
tv.columns
# Out:
# Index(['Brand', 'Resolution', 'Size ', 'Selling Price', 'Original Price',
#        'Operating System', 'Rating'],
#       dtype='object')

# %%
tv.columns=["brand","resolution","size","selling_price","original_price","operating_system","rating"]

# %%
tv.head()
# Out:
#      brand     resolution  size  selling_price  original_price  \
# 0  TOSHIBA   Ultra HD LED    55          37999           54990
# 1     TCL   QLED Ultra HD    55          52999          129990
# 2  realme          HD LED    32          13999           17999
# 3      Mi          HD LED    32          14999           19999
# 4  realme          HD LED    32          12999           21999
#
#   operating_system  rating
# 0            VIDAA     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
tv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             912 non-null    object
#  1   resolution        912 non-null    object
#  2   size              912 non-null    int64
#  3   selling_price     912 non-null    int64
#  4   original_price    912 non-null    int64
#  5   operating_system  901 non-null    object
#  6   rating            692 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 50.0+ KB

# %%
for i in tv.columns:
    print(i)
    print("_"*10)
    print(tv[i].unique())
    print("_"*75)
# Out:
# brand
# __________
# ['TOSHIBA' 'TCL ' 'realme ' 'Mi ' 'OnePlus' 'Hisense' 'LG '
#  'MarQ by Flipkart' 'iFFALCON by TCL' 'Coocaa ' 'SAMSUNG' 'Infinix' 'Vu'
#  'Nokia ' 'Thomson' 'SONY ' 'KODAK ' 'MOTOROLA' 'PHILIPS' 'Acer'
#  'Blaupunkt' 'Adsun' 'T-Series' 'Panasonic' 'Micromax' 'Sansui ' 'Croma '
#  'Candes ' 'Dyanora' 'Haier ' 'Onida' 'RGL ' 'Lloyd ' 'LumX ' 'Onix '
#  'IMPEX ' 'BPL ' 'CloudWalker' 'Oxygen ' 'Power Guard' 'Akai ' 'VG '
#  'Sun King' 'Compaq ' 'HUIDI ' 'Intex ' 'DETEL ' 'JVC' 'G-TEN ' 'Skyworth'
#  'Maser ' 'Sanyo ' 'MURPHY ' 'Samsung' 'Dektron' 'Sharp ' 'KRISONS'
#  'Weston ' 'AISEN  ']
# ___________________________________________________________________________
# resolution
# __________
# ['Ultra HD LED' 'QLED Ultra HD' 'HD LED' 'Full HD LED' 'HD Plasma']
# ___________________________________________________________________________
# size
# __________
# [55 32 43 65 40 50 70 24 42 58 49 39 48 75 85 31 28 20 22 21 52 46 60 47
#  19 38 17]
# ...

# %%
tv.isna()
# Out:
#      brand  resolution   size  selling_price  original_price  \
# 0    False       False  False          False           False
# 1    False       False  False          False           False
# 2    False       False  False          False           False
# 3    False       False  False          False           False
# 4    False       False  False          False           False
# ..     ...         ...    ...            ...             ...
# 907  False       False  False          False           False
# 908  False       False  False          False           False
# 909  False       False  False          False           False
# 910  False       False  False          False           False
# 911  False       False  False          False           False
#
#      operating_system  rating
# 0               False   False
# 1               False   False
# 2               False   False
# 3               False   False
# 4               False   False
# ..                ...     ...
# ...

# %%
tv.isna().sum()
# Out:
# brand                 0
# resolution            0
# size                  0
# selling_price         0
# original_price        0
# operating_system     11
# rating              220
# dtype: int64

# %%
tv.isna().sum()
# Out:
# brand                 0
# resolution            0
# size                  0
# selling_price         0
# original_price        0
# operating_system     11
# rating              220
# dtype: int64

# %%
tv["operating_system"].replace(np.nan,"others",inplace=True)

# %%
tv.isna().sum()
# Out:
# brand                 0
# resolution            0
# size                  0
# selling_price         0
# original_price        0
# operating_system      0
# rating              220
# dtype: int64

# %%
tv.loc[tv["operating_system"]=="others"]
# Out:
#                 brand   resolution  size  selling_price  original_price  \
# 20   MarQ by Flipkart       HD LED    32           9999           19999
# 414          Sun King       HD LED    32          24999           49998
# 558          Skyworth       HD LED    24           8659           12490
# 559            Maser        HD LED    24           7499            7999
# 585           MURPHY   Full HD LED    32          12990           16990
# 813  MarQ by Flipkart       HD LED    24           7499           14999
# 814  MarQ by Flipkart  Full HD LED    24           6999           11499
# 815  MarQ by Flipkart  Full HD LED    32           9499           16499
# 828           MURPHY   Full HD LED    32          13990           14999
# 829           MURPHY        HD LED    24           7490           12990
# 851           PHILIPS  Full HD LED    22           6649           12990
#
#     operating_system  rating
# 20            others     4.3
# 414           others     NaN
# ...

# %%
tv[tv["rating"]=="not provided"]
# Out:
# Empty DataFrame
# Columns: [brand, resolution, size, selling_price, original_price, operating_system, rating]
# Index: []

# %%
tv["rating"].value_counts()
# Out:
# rating
# 4.3    156
# 4.4    121
# 4.2     77
# 4.1     55
# 4.5     48
# 4.0     38
# 3.9     35
# 4.7     27
# 3.8     25
# 3.7     23
# 4.6     20
# 5.0     18
# 4.8     16
# 3.6      9
# 3.0      5
# 3.3      3
# 3.5      3
# 2.7      3
# 4.9      2
# 3.4      2
# 2.8      2
# 2.4      1
# 2.0      1
# 2.5      1
# 2.6      1
# Name: count, dtype: int64

# %%
tv["operating_system"].value_counts()
# Out:
# operating_system
# Android      474
# Tizen        145
# Linux        127
# WebOS        109
# HomeOS        28
# VIDAA         13
# others        11
# FireTV OS      5
# Name: count, dtype: int64

# %%
tv["brand"].str.upper()
# Out:
# 0      TOSHIBA
# 1         TCL
# 2      REALME
# 3          MI
# 4      REALME
#         ...
# 907      SONY
# 908      SONY
# 909      SONY
# 910      SONY
# 911      SONY
# Name: brand, Length: 912, dtype: object

# %%
tv["brand"]=tv["brand"].str.upper()

# %%
tv.head()
# Out:
#      brand     resolution  size  selling_price  original_price  \
# 0  TOSHIBA   Ultra HD LED    55          37999           54990
# 1     TCL   QLED Ultra HD    55          52999          129990
# 2  REALME          HD LED    32          13999           17999
# 3      MI          HD LED    32          14999           19999
# 4  REALME          HD LED    32          12999           21999
#
#   operating_system  rating
# 0            VIDAA     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
tv["brand"].unique()
# Out:
# array(['TOSHIBA', 'TCL ', 'REALME ', 'MI ', 'ONEPLUS', 'HISENSE', 'LG ',
#        'MARQ BY FLIPKART', 'IFFALCON BY TCL', 'COOCAA ', 'SAMSUNG',
#        'INFINIX', 'VU', 'NOKIA ', 'THOMSON', 'SONY ', 'KODAK ',
#        'MOTOROLA', 'PHILIPS', 'ACER', 'BLAUPUNKT', 'ADSUN', 'T-SERIES',
#        'PANASONIC', 'MICROMAX', 'SANSUI ', 'CROMA ', 'CANDES ', 'DYANORA',
#        'HAIER ', 'ONIDA', 'RGL ', 'LLOYD ', 'LUMX ', 'ONIX ', 'IMPEX ',
#        'BPL ', 'CLOUDWALKER', 'OXYGEN ', 'POWER GUARD', 'AKAI ', 'VG ',
#        'SUN KING', 'COMPAQ ', 'HUIDI ', 'INTEX ', 'DETEL ', 'JVC',
#        'G-TEN ', 'SKYWORTH', 'MASER ', 'SANYO ', 'MURPHY ', 'DEKTRON',
#        'SHARP ', 'KRISONS', 'WESTON ', 'AISEN  '], dtype=object)

# %%
tv.groupby(["brand"])["operating_system"].count()
# Out:
# brand
# ACER                  9
# ADSUN                 7
# AISEN                 8
# AKAI                  6
# BLAUPUNKT            15
# BPL                   4
# CANDES               12
# CLOUDWALKER           9
# COMPAQ                5
# COOCAA                9
# CROMA                12
# DEKTRON               4
# DETEL                 3
# DYANORA               6
# G-TEN                 8
# HAIER                18
# HISENSE              10
# HUIDI                 6
# IFFALCON BY TCL      19
# IMPEX                13
# INFINIX               3
# INTEX                 7
# JVC                   6
# KODAK                15
# KRISONS               3
# LG                  122
# LLOYD                22
# LUMX                  6
# MARQ BY FLIPKART      8
# MASER                 1
# MI                   19
# MICROMAX             25
# MOTOROLA             15
# MURPHY                4
# NOKIA                11
# ONEPLUS               9
# ONIDA                12
# ONIX                  8
# ...

# %%
k=tv.groupby(["brand"],as_index=False)["operating_system"].count().sort_values("operating_system",ascending=0).head(10)

# %%
k
# Out:
#               brand  operating_system
# 44          SAMSUNG               146
# 25              LG                122
# 49            SONY                 62
# 52             TCL                 44
# 39        PANASONIC                30
# 31         MICROMAX                25
# 56               VU                23
# 26           LLOYD                 22
# 30              MI                 19
# 18  IFFALCON BY TCL                19

# %%
tv.brand.value_counts().head(10)
# Out:
# brand
# SAMSUNG            146
# LG                 122
# SONY                62
# TCL                 44
# PANASONIC           30
# MICROMAX            25
# VU                  23
# LLOYD               22
# MI                  19
# IFFALCON BY TCL     19
# Name: count, dtype: int64

# %%
def malli(plot,title,xlabel,ylabel):
    plot.set_xlabel(xlabel,fontsize=16,weight="bold")
    plot.set_ylabel(ylabel,fontsize=13,weight="bold")
    plot.set_title(title,fontsize=15,weight="bold")

# %%
plt.figure(figsize=(15,6))
sns.set_style("whitegrid")
ax=sns.countplot(data=tv,x="brand",color="orange")
malli(ax,"vizualize the brands sales","products","sales")
ax.tick_params("x",rotation=90)
for i in ax.containers:
    ax.bar_label(i)

# %%
plt.figure(figsize=(15,6))
plt.bar(k["brand"],k["operating_system"],edgecolor="black")
plt.title("vizualize which has more sales")
plt.xlabel("products")
plt.ylabel("sales")
plt.bar_label(plt.gca().containers[0],fmt="%.f")
plt.show()

# %%
tv.head()
# Out:
#      brand     resolution  size  selling_price  original_price  \
# 0  TOSHIBA   Ultra HD LED    55          37999           54990
# 1     TCL   QLED Ultra HD    55          52999          129990
# 2  REALME          HD LED    32          13999           17999
# 3      MI          HD LED    32          14999           19999
# 4  REALME          HD LED    32          12999           21999
#
#   operating_system  rating
# 0            VIDAA     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
f=(tv["original_price"]-tv["selling_price"])*100/tv["original_price"]

# %%
f=np.ceil(f)

# %%
tv.insert(5,column="dicount(%)",value=f)

# %%
tv.head()
# Out:
#      brand     resolution  size  selling_price  original_price  dicount(%)  \
# 0  TOSHIBA   Ultra HD LED    55          37999           54990        31.0
# 1     TCL   QLED Ultra HD    55          52999          129990        60.0
# 2  REALME          HD LED    32          13999           17999        23.0
# 3      MI          HD LED    32          14999           19999        26.0
# 4  REALME          HD LED    32          12999           21999        41.0
#
#   operating_system  rating
# 0            VIDAA     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
tv["operating_system"]=tv["operating_system"].str.capitalize()

# %%
tv.head()
# Out:
#      brand     resolution  size  selling_price  original_price  dicount(%)  \
# 0  TOSHIBA   Ultra HD LED    55          37999           54990        31.0
# 1     TCL   QLED Ultra HD    55          52999          129990        60.0
# 2  REALME          HD LED    32          13999           17999        23.0
# 3      MI          HD LED    32          14999           19999        26.0
# 4  REALME          HD LED    32          12999           21999        41.0
#
#   operating_system  rating
# 0            Vidaa     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
tv.nunique()
# Out:
# brand                58
# resolution            5
# size                 27
# selling_price       515
# original_price      455
# dicount(%)           72
# operating_system      8
# rating               25
# dtype: int64

# %%
colors = ["#EF233C","#eb5e28","#d68c45","#00bbf9","#274c77"]
palette = sns.color_palette(palette = colors)

sns.palplot(palette, size =1)
plt.show()

# %%
tv['brand'].groupby(tv['resolution']).count().sort_values(ascending=False)
# Out:
# resolution
# Ultra HD LED     399
# HD LED           229
# Full HD LED      220
# QLED Ultra HD     60
# HD Plasma          4
# Name: brand, dtype: int64

# %%
tv.head()
# Out:
#      brand     resolution  size  selling_price  original_price  dicount(%)  \
# 0  TOSHIBA   Ultra HD LED    55          37999           54990        31.0
# 1     TCL   QLED Ultra HD    55          52999          129990        60.0
# 2  REALME          HD LED    32          13999           17999        23.0
# 3      MI          HD LED    32          14999           19999        26.0
# 4  REALME          HD LED    32          12999           21999        41.0
#
#   operating_system  rating
# 0            Vidaa     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
tv.groupby(["resolution"]).size()
# Out:
# resolution
# Full HD LED      220
# HD LED           229
# HD Plasma          4
# QLED Ultra HD     60
# Ultra HD LED     399
# dtype: int64

# %%
v=tv.groupby(["resolution"],as_index=False).size().sort_values("size",ascending=0)

# %%
labels = 'Ultra HD LED', 'QLED Ultra HD', 'HD LED', 'Full HD LED','HD Plasma'
sizes = [399,229,220,60,4]
fig, ax = plt.subplots(figsize=(10,6))
fig.set_facecolor('white')
ax.pie(sizes, labels=labels, colors=["#EF233C","#eb5e28","#3a0ca3","#d68c45","#00bbf9"],autopct='%1.1f%%', startangle=60,textprops={'color':'black','weight':'bold','fontsize':12.5})
ax.axis('equal')
plt.show()

# %%
v.head()
# Out:
#       resolution  size
# 4   Ultra HD LED   399
# 1         HD LED   229
# 0    Full HD LED   220
# 3  QLED Ultra HD    60
# 2      HD Plasma     4

# %%
plt.pie(v["size"],labels=v["resolution"])
plt.show()

# %%
plt.pie(v["size"],labels=v["resolution"])
plt.axis("equal")
plt.show()

# %%
plt.pie(v["size"],labels=v["resolution"],shadow=True,explode=(0.05,0.05,0.05,0.05,0.05),autopct="%1.1f%%")
plt.xlabel("tv resolution",fontsize=15,weight="bold")
plt.show()

# %%
plt.pie(v["size"],labels=v["resolution"],shadow=True,explode=(0.05,0.05,0.05,0.05,0.05),autopct="%1.1f%%")
plt.xlabel("tv resolution",fontsize=15,weight="bold")
plt.axis("equal")
plt.show()

# %%
plt.pie(v["size"],labels=v["resolution"],shadow=True,explode=(0.05,0.05,0.05,0.05,0.05),autopct="%1.1f%%",textprops={"fontsize":12,"weight":"bold"})
plt.xlabel("tv resolution",fontsize=15,weight="bold")
plt.axis("equal")
plt.show()

# %%
tv['brand'].groupby(tv['brand']).count().sort_values(ascending=False).iloc[:5]
# Out:
# brand
# SAMSUNG      146
# LG           122
# SONY          62
# TCL           44
# PANASONIC     30
# Name: brand, dtype: int64

# %%
sns.set_style('white')
plt.figure(figsize=(10,7))
sns.countplot(y="brand", hue="resolution", data=tv, palette=colors,order=tv["brand"].value_counts().iloc[:5].index)
# Out:
# <Axes: xlabel='count', ylabel='brand'>

# %%
tv.head()
# Out:
#      brand     resolution  size  selling_price  original_price  dicount(%)  \
# 0  TOSHIBA   Ultra HD LED    55          37999           54990        31.0
# 1     TCL   QLED Ultra HD    55          52999          129990        60.0
# 2  REALME          HD LED    32          13999           17999        23.0
# 3      MI          HD LED    32          14999           19999        26.0
# 4  REALME          HD LED    32          12999           21999        41.0
#
#   operating_system  rating
# 0            Vidaa     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
plt.figure(figsize=(15,6))
ax=sns.countplot(y="brand",hue="resolution",data=tv,order=tv["brand"].head())
malli(ax,"resoultion analysis brand wise","sales","brand")

# %%
plt.figure(figsize=(15,6))
ax=sns.countplot(y="brand",hue="resolution",data=tv,palette="husl",order=tv["brand"].head())
malli(ax,"resoultion analysis brand wise","sales","brand")

# %%
plt.figure(figsize=(15,6))
ax=sns.countplot(y="brand",hue="resolution",data=tv,palette="husl",order=tv["brand"].value_counts().sort_values(ascending=0).head().index)
malli(ax,"resoultion analysis brand wise","sales","brand")
plt.show()

# %%
plt.figure(figsize=(15,6))
ax=sns.countplot(y="brand",hue="resolution",data=tv,palette="husl",order=tv["brand"].value_counts().sort_values(ascending=0).head().index)
malli(ax,"resolution analysis brand wise","sales","brand")
for i in ax.containers:
    ax.bar_label(i)

# %%
a.isna().sum()
# Out:
# Brand                 0
# Resolution            0
# Size                  0
# Selling Price         0
# Original Price        0
# Operating System     11
# Rating              220
# dtype: int64

# %%
round(a.groupby('Brand')['Rating'].mean().sort_values(ascending=False),1)
# Out:
# Brand
# SONY                4.5
# OnePlus             4.4
# Hisense             4.4
# Haier               4.4
# Vu                  4.4
# TOSHIBA             4.4
# MOTOROLA            4.3
# Mi                  4.3
# Compaq              4.3
# Onida               4.3
# Thomson             4.3
# Onix                4.3
# KODAK               4.3
# Dektron             4.3
# iFFALCON by TCL     4.3
# LG                  4.3
# realme              4.3
# SAMSUNG             4.3
# MarQ by Flipkart    4.3
# Nokia               4.3
# Coocaa              4.2
# Blaupunkt           4.2
# Weston              4.2
# TCL                 4.2
# Sanyo               4.2
# Infinix             4.2
# Intex               4.2
# Panasonic           4.2
# IMPEX               4.1
# Croma               4.1
# Sansui              4.1
# Micromax            4.1
# PHILIPS             4.1
# HUIDI               4.1
# CloudWalker         4.1
# Samsung             4.1
# Lloyd               4.1
# Candes              4.1
# ...

# %%
round(a.groupby(["Brand"])["Rating"].mean().sort_values(ascending=0),1)
# Out:
# Brand
# SONY                4.5
# OnePlus             4.4
# Hisense             4.4
# Haier               4.4
# Vu                  4.4
# TOSHIBA             4.4
# MOTOROLA            4.3
# Mi                  4.3
# Compaq              4.3
# Onida               4.3
# Thomson             4.3
# Onix                4.3
# KODAK               4.3
# Dektron             4.3
# iFFALCON by TCL     4.3
# LG                  4.3
# realme              4.3
# SAMSUNG             4.3
# MarQ by Flipkart    4.3
# Nokia               4.3
# Coocaa              4.2
# Blaupunkt           4.2
# Weston              4.2
# TCL                 4.2
# Sanyo               4.2
# Infinix             4.2
# Intex               4.2
# Panasonic           4.2
# IMPEX               4.1
# Croma               4.1
# Sansui              4.1
# Micromax            4.1
# PHILIPS             4.1
# HUIDI               4.1
# CloudWalker         4.1
# Samsung             4.1
# Lloyd               4.1
# Candes              4.1
# ...

# %%
round(a.groupby(["Brand"])["Rating"].mean().sort_values(ascending=0),2)
# Out:
# Brand
# SONY                4.52
# OnePlus             4.39
# Hisense             4.37
# Haier               4.37
# Vu                  4.36
# TOSHIBA             4.35
# MOTOROLA            4.33
# Mi                  4.32
# Compaq              4.32
# Onida               4.31
# Thomson             4.30
# Onix                4.30
# KODAK               4.30
# Dektron             4.30
# iFFALCON by TCL     4.29
# LG                  4.29
# realme              4.29
# SAMSUNG             4.28
# MarQ by Flipkart    4.28
# Nokia               4.27
# Coocaa              4.24
# Blaupunkt           4.24
# Weston              4.24
# TCL                 4.22
# Sanyo               4.20
# Infinix             4.20
# Intex               4.19
# Panasonic           4.18
# IMPEX               4.15
# Croma               4.14
# Sansui              4.14
# Micromax            4.13
# PHILIPS             4.12
# HUIDI               4.10
# CloudWalker         4.09
# Samsung             4.08
# ...

# %%
# Rating vs Selling Price
#filter by Known Brands
list1 = ["SONY","OnePlus","Haier","Vu","TOSHIBA","MOTOROLA","Mi","Compaq","Onida","Thomson",
        "KODAK","LG","realme","SAMSUNG","Nokia","Panasonic","Sansui","Micromax","PHILIPS","Samsung","JVC"]

list2 = ["Hisense","Thomson","Onix","KODAK","Dektron","iFFALCON by TCL","MarQ by Flipkart","Nokia","Coocaa","Blaupunkt","Weston","TCL",
        "Infinix","Sanyo","Intex","IMPEX","Croma","HUIDI","CloudWalker","Lloyd", 
        "Candes","Detel","LumX"]
series1 = a["Brand"].isin(list1)
series2 = a["Brand"].isin(list2)
df_f1= a[series1]
df_f2= a[series2]
fig, axs = plt.subplots(ncols=2,figsize=(20,5))
ax1 = sns.stripplot(x="Rating", y="Selling Price", data=df_f1,hue="Brand", palette=colors,ax=axs[0])
ax2 = sns.stripplot(x="Rating", y="Selling Price", data=df_f2,hue="Brand", palette=colors,ax=axs[1])

# %%
plt.figure(figsize=(15,17))
ax=sns.stripplot(x="Rating",y="Selling Price",data=a,hue="Brand")
plt.show()

# %%
plt.figure(figsize=(15,17))
ax=sns.stripplot(x="rating",y="selling_price",data=tv,hue="brand")
plt.show()

# %%
tv.shape
# Out:
# (912, 8)

# %%
tv["brand"].unique()
# Out:
# array(['TOSHIBA', 'TCL ', 'REALME ', 'MI ', 'ONEPLUS', 'HISENSE', 'LG ',
#        'MARQ BY FLIPKART', 'IFFALCON BY TCL', 'COOCAA ', 'SAMSUNG',
#        'INFINIX', 'VU', 'NOKIA ', 'THOMSON', 'SONY ', 'KODAK ',
#        'MOTOROLA', 'PHILIPS', 'ACER', 'BLAUPUNKT', 'ADSUN', 'T-SERIES',
#        'PANASONIC', 'MICROMAX', 'SANSUI ', 'CROMA ', 'CANDES ', 'DYANORA',
#        'HAIER ', 'ONIDA', 'RGL ', 'LLOYD ', 'LUMX ', 'ONIX ', 'IMPEX ',
#        'BPL ', 'CLOUDWALKER', 'OXYGEN ', 'POWER GUARD', 'AKAI ', 'VG ',
#        'SUN KING', 'COMPAQ ', 'HUIDI ', 'INTEX ', 'DETEL ', 'JVC',
#        'G-TEN ', 'SKYWORTH', 'MASER ', 'SANYO ', 'MURPHY ', 'DEKTRON',
#        'SHARP ', 'KRISONS', 'WESTON ', 'AISEN  '], dtype=object)

# %%
k=['TOSHIBA', 'TCL ', 'REALME ', 'MI ', 'ONEPLUS', 'HISENSE', 'LG ',
       'MARQ BY FLIPKART', 'IFFALCON BY TCL', 'COOCAA ', 'SAMSUNG',
       'INFINIX', 'VU', 'NOKIA ', 'THOMSON', 'SONY ', 'KODAK ',
       'MOTOROLA', 'PHILIPS', 'ACER', 'BLAUPUNKT', 'ADSUN', 'T-SERIES',
       'PANASONIC', 'MICROMAX', 'SANSUI ', 'CROMA ', 'CANDES ', 'DYANORA',
       'HAIER ', 'ONIDA', 'RGL ', 'LLOYD ', 'LUMX ']
y=[ 'ONIX ', 'IMPEX ',
       'BPL ', 'CLOUDWALKER', 'OXYGEN ', 'POWER GUARD', 'AKAI ', 'VG ',
       'SUN KING', 'COMPAQ ', 'HUIDI ', 'INTEX ', 'DETEL ', 'JVC',
       'G-TEN ', 'SKYWORTH', 'MASER ', 'SANYO ', 'MURPHY ', 'DEKTRON',
       'SHARP ', 'KRISONS', 'WESTON ', 'AISEN  ']
j=tv.loc[tv["brand"].isin(k)]
l=tv.loc[tv["brand"].isin(y)]
plt.figure(figsize=(15,15))
ax=sns.stripplot(x="rating",y="selling_price",hue="brand",data=j)
plt.show()
plt.figure(figsize=(15,15))
ax=sns.stripplot(x="rating",y="selling_price",hue="brand",data=j)
plt.show()

# %%
k=['TOSHIBA', 'TCL ', 'REALME ', 'MI ', 'ONEPLUS', 'HISENSE', 'LG ',
       'MARQ BY FLIPKART', 'IFFALCON BY TCL', 'COOCAA ', 'SAMSUNG',
       'INFINIX', 'VU', 'NOKIA ', 'THOMSON', 'SONY ', 'KODAK ',
       'MOTOROLA', 'PHILIPS', 'ACER', 'BLAUPUNKT', 'ADSUN', 'T-SERIES',
       'PANASONIC', 'MICROMAX', 'SANSUI ', 'CROMA ', 'CANDES ', 'DYANORA',
       'HAIER ', 'ONIDA', 'RGL ', 'LLOYD ', 'LUMX ']
y=[ 'ONIX ', 'IMPEX ',
       'BPL ', 'CLOUDWALKER', 'OXYGEN ', 'POWER GUARD', 'AKAI ', 'VG ',
       'SUN KING', 'COMPAQ ', 'HUIDI ', 'INTEX ', 'DETEL ', 'JVC',
       'G-TEN ', 'SKYWORTH', 'MASER ', 'SANYO ', 'MURPHY ', 'DEKTRON',
       'SHARP ', 'KRISONS', 'WESTON ', 'AISEN  ']
d=tv["brand"].isin(y)
f=tv["brand"].isin(k)
d=tv[d]
f=tv[f]
fig,axs=plt.subplots(ncols=2,figsize=(20,15))
ax1=sns.stripplot(x="rating",y="selling_price",data=d,hue="brand",palette=colors,ax=axs[0])
ax2=sns.stripplot(x="rating",y="selling_price",data=f,hue="brand",palette=colors,ax=axs[1])

# %%
list1 = ["SONY","OnePlus","Haier","Vu","TOSHIBA","MOTOROLA","Mi","Compaq","Onida","Thomson",
        "KODAK","LG","realme","SAMSUNG","Nokia","Panasonic","Sansui","Micromax","PHILIPS","Samsung","JVC"]

list2 = ["Hisense","Thomson","Onix","KODAK","Dektron","iFFALCON by TCL","MarQ by Flipkart","Nokia","Coocaa","Blaupunkt","Weston","TCL",
        "Infinix","Sanyo","Intex","IMPEX","Croma","HUIDI","CloudWalker","Lloyd", 
        "Candes","Detel","LumX"]
series1 = a["Brand"].isin(list1)
series2 = a["Brand"].isin(list2)
df_f1= a[series1]
df_f2= a[series2]
fig, axs = plt.subplots(ncols=2,figsize=(20,5))
ax1 = sns.stripplot(x="Rating", y="Selling Price", data=df_f1,hue="Brand", palette=colors,ax=axs[0])
ax2 = sns.stripplot(x="Rating", y="Selling Price", data=df_f2,hue="Brand", palette=colors,ax=axs[1])

# %%
# !pip install altair

# %%
import altair as alt
alt.Chart(tv).mark_point(filled=True,size=40).encode(
    x='original_price',
    y='selling_price',
    color='brand',
    tooltip=['brand', 'selling_price', 'original_price']
).interactive()
# Out:
# alt.Chart(...)

# %%
sns.barplot(x=tv['resolution'], y=tv['selling_price'],palette=colors)
plt.xticks(rotation="vertical")
plt.show()

# %%
tv.head()
# Out:
#      brand     resolution  size  selling_price  original_price  dicount(%)  \
# 0  TOSHIBA   Ultra HD LED    55          37999           54990        31.0
# 1     TCL   QLED Ultra HD    55          52999          129990        60.0
# 2  REALME          HD LED    32          13999           17999        23.0
# 3      MI          HD LED    32          14999           19999        26.0
# 4  REALME          HD LED    32          12999           21999        41.0
#
#   operating_system  rating
# 0            Vidaa     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
l=tv.groupby(["resolution"],as_index=False)["selling_price"].sum()

# %%
l
# Out:
#       resolution  selling_price
# 0    Full HD LED       11598405
# 1         HD LED        3542930
# 2      HD Plasma         228980
# 3  QLED Ultra HD        7525047
# 4   Ultra HD LED       31239687

# %%
plt.figure(figsize=(15,6))
plt.bar(l["resolution"],l["selling_price"])
plt.title("vizualize the resolution profits")
plt.xlabel("tv resolution model",fontsize=12,weight="bold")
plt.ylabel("sales profit",fontsize=12,weight="bold")
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.bar(tv["resolution"],tv["selling_price"])
plt.title("vizualize the resolution profits")
plt.xlabel("tv resolution model",fontsize=12,weight="bold")
plt.ylabel("sales profit",fontsize=12,weight="bold")
plt.show()

# %%
sns.barplot(x="resolution",y="selling_price",data=l,color="orange")
plt.show()

# %%
sns.barplot(x="resolution",y="selling_price",data=tv,color="orange")
plt.show()

# %%
w=tv.groupby(["resolution"],as_index=False)["selling_price"].count()

# %%
w
# Out:
#       resolution  selling_price
# 0    Full HD LED            220
# 1         HD LED            229
# 2      HD Plasma              4
# 3  QLED Ultra HD             60
# 4   Ultra HD LED            399

# %%
plt.pie(x=w["selling_price"],labels=w["resolution"],shadow=True,explode=(0.03,0.03,0.03,0.03,0.03),autopct="%1.1f%%")
plt.axis("equal")
plt.show()

# %%
tv.groupby('brand')['selling_price'].mean().sort_values(ascending=False).apply(np.ceil)
# Out:
# brand
# SHARP               149672.0
# SAMSUNG             107035.0
# LG                   96915.0
# HISENSE              89796.0
# SONY                 89343.0
# TCL                  55799.0
# IFFALCON BY TCL      54235.0
# PANASONIC            53494.0
# AKAI                 52003.0
# ONEPLUS              47376.0
# VU                   46650.0
# COMPAQ               45999.0
# SANYO                45499.0
# WESTON               43390.0
# OXYGEN               40327.0
# NOKIA                38863.0
# TOSHIBA              38853.0
# MOTOROLA             38399.0
# SANSUI               37672.0
# HAIER                36617.0
# AISEN                35463.0
# BPL                  34618.0
# ONIX                 34217.0
# LLOYD                34162.0
# PHILIPS              34114.0
# JVC                  32497.0
# CLOUDWALKER          32332.0
# ACER                 31665.0
# MI                   30788.0
# POWER GUARD          30510.0
# ONIDA                29708.0
# IMPEX                28820.0
# ...

# %%
np.ceil(tv.groupby("brand")["selling_price"].mean().sort_values(ascending=0))
# Out:
# brand
# SHARP               149672.0
# SAMSUNG             107035.0
# LG                   96915.0
# HISENSE              89796.0
# SONY                 89343.0
# TCL                  55799.0
# IFFALCON BY TCL      54235.0
# PANASONIC            53494.0
# AKAI                 52003.0
# ONEPLUS              47376.0
# VU                   46650.0
# COMPAQ               45999.0
# SANYO                45499.0
# WESTON               43390.0
# OXYGEN               40327.0
# NOKIA                38863.0
# TOSHIBA              38853.0
# MOTOROLA             38399.0
# SANSUI               37672.0
# HAIER                36617.0
# AISEN                35463.0
# BPL                  34618.0
# ONIX                 34217.0
# LLOYD                34162.0
# PHILIPS              34114.0
# JVC                  32497.0
# CLOUDWALKER          32332.0
# ACER                 31665.0
# MI                   30788.0
# POWER GUARD          30510.0
# ONIDA                29708.0
# IMPEX                28820.0
# ...

# %%
df_p1=tv[(tv["selling_price"] >=10000) & (tv["selling_price"] <= 100000)]
df_p1.iloc[:20]
# Out:
#       brand     resolution  size  selling_price  original_price  dicount(%)  \
# 0   TOSHIBA   Ultra HD LED    55          37999           54990        31.0
# 1      TCL   QLED Ultra HD    55          52999          129990        60.0
# 2   REALME          HD LED    32          13999           17999        23.0
# 3       MI          HD LED    32          14999           19999        26.0
# 4   REALME          HD LED    32          12999           21999        41.0
# 5   ONEPLUS         HD LED    32          15999           19999        21.0
# 6   ONEPLUS    Full HD LED    43          25999           29999        14.0
# 7      TCL    Ultra HD LED    65          57999          119990        52.0
# 8       MI     Full HD LED    40          21999           29999        27.0
# 9   REALME    Ultra HD LED    43          26999           32999        19.0
# 10      MI    Ultra HD LED    43          27999           34999        21.0
# ...

# %%
p=tv["selling_price"]>10000
e=tv["selling_price"]<100000
d=tv.loc[p&e]

# %%
d
# Out:
#        brand     resolution  size  selling_price  original_price  dicount(%)  \
# 0    TOSHIBA   Ultra HD LED    55          37999           54990        31.0
# 1       TCL   QLED Ultra HD    55          52999          129990        60.0
# 2    REALME          HD LED    32          13999           17999        23.0
# 3        MI          HD LED    32          14999           19999        26.0
# 4    REALME          HD LED    32          12999           21999        41.0
# ..       ...            ...   ...            ...             ...         ...
# 906    SONY    Ultra HD LED    49          54999          114900        53.0
# 907    SONY     Full HD LED    43          44999           57900        23.0
# 908    SONY     Full HD LED    40          41499           51900        21.0
# 910    SONY          HD LED    32          32900           32900         0.0
# 911    SONY     Full HD LED    43          56900           56900         0.0
#
#     operating_system  rating
# ...

# %%
tv.shape
# Out:
# (912, 8)

# %%
fig, ax = plt.subplots(figsize=(20,5))
ax = sns.boxplot(x="brand", y="selling_price", data=tv,palette=colors)
ax.tick_params("x",rotation=90)

# %%
g=tv[(tv["selling_price"]>10000) & (tv["selling_price"]<100000)]

# %%
g.iloc[:2]
# Out:
#      brand     resolution  size  selling_price  original_price  dicount(%)  \
# 0  TOSHIBA   Ultra HD LED    55          37999           54990        31.0
# 1     TCL   QLED Ultra HD    55          52999          129990        60.0
#
#   operating_system  rating
# 0            Vidaa     4.3
# 1          Android     4.4

# %%
sns.barplot(x=tv['operating_system'], y=tv['selling_price'],palette=colors)
plt.xticks(rotation="vertical")
plt.show()

# %%
plt.bar(tv["operating_system"],tv["selling_price"])
plt.show()

# %%
tv.head()
# Out:
#      brand     resolution  size  selling_price  original_price  dicount(%)  \
# 0  TOSHIBA   Ultra HD LED    55          37999           54990        31.0
# 1     TCL   QLED Ultra HD    55          52999          129990        60.0
# 2  REALME          HD LED    32          13999           17999        23.0
# 3      MI          HD LED    32          14999           19999        26.0
# 4  REALME          HD LED    32          12999           21999        41.0
#
#   operating_system  rating
# 0            Vidaa     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
tv.groupby(["operating_system"])["selling_price"].sum()
# Out:
# operating_system
# Android      19282220
# Firetv os      152450
# Homeos         510485
# Linux         6395592
# Others         116272
# Tizen        15581672
# Vidaa          505087
# Webos        11591271
# Name: selling_price, dtype: int64

# %%
tv.groupby(["operating_system"])["selling_price"].count()
# Out:
# operating_system
# Android      474
# Firetv os      5
# Homeos        28
# Linux        127
# Others        11
# Tizen        145
# Vidaa         13
# Webos        109
# Name: selling_price, dtype: int64
